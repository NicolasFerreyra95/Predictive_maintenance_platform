# %%
#Conectar con sql
import pandas as pd
from sqlalchemy import create_engine
ta = pd.read_csv("../data/raw/ai4i2020.csv")

#Corrección de nombres
ta = ta.rename(columns={
    "Product ID": "product_id",
    "Air temperature [K]": "air_temp_k",
    "Process temperature [K]":"process_temp_k",
    "Rotational speed [rpm]": "rot_speed_rpm",
    "Torque [Nm]": "torque_nm",
    "Tool wear [min]": "tool_wear_min",
    "Machine failure": "machine_failure"
})
ta
# Out:
#         UDI product_id Type  air_temp_k  process_temp_k  rot_speed_rpm  \
# 0         1     M14860    M       298.1           308.6           1551
# 1         2     L47181    L       298.2           308.7           1408
# 2         3     L47182    L       298.1           308.5           1498
# 3         4     L47183    L       298.2           308.6           1433
# 4         5     L47184    L       298.2           308.7           1408
# ...     ...        ...  ...         ...             ...            ...
# 9995   9996     M24855    M       298.8           308.4           1604
# 9996   9997     H39410    H       298.9           308.4           1632
# 9997   9998     M24857    M       299.0           308.6           1645
# 9998   9999     H39412    H       299.0           308.7           1408
# 9999  10000     M24859    M       299.0           308.7           1500
#
#       torque_nm  tool_wear_min  machine_failure  TWF  HDF  PWF  OSF  RNF
# 0          42.8              0                0    0    0    0    0    0
# 1          46.3              3                0    0    0    0    0    0
# 2          49.4              5                0    0    0    0    0    0
# 3          39.5              7                0    0    0    0    0    0
# 4          40.0              9                0    0    0    0    0    0
# ...         ...            ...              ...  ...  ...  ...  ...  ...
# 9995       29.5             14                0    0    0    0    0    0
# 9996       31.8             17                0    0    0    0    0    0
# 9997       33.4             22                0    0    0    0    0    0
# 9998       48.5             25                0    0    0    0    0    0
# 9999       40.2             30                0    0    0    0    0    0
#
# [10000 rows x 14 columns]

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:nieve@localhost:5432/prev_maintenance",connect_args={'connect_timeout': 5}
)
#Verificación
with engine.connect() as conn:
    result = conn.exec_driver_sql(
        "SELECT current_database();"
    )

    for row in result:
        print(row)
# Out:
# ('prev_maintenance',)

# %%
#Datos para products
ta.to_sql(
    "rawdata",
    engine,
    if_exists="replace",    index=False)

print("Data set")
# Out:
# Data set
